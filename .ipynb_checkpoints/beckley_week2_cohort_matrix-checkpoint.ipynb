# %%
import pandas as pd
import numpy as np

# %%
# ============================================
# WEEK 2 - COHORT RETENTION MATRIX
# Owner: Beckley
# ============================================

# Load the dataset
df = pd.read_csv('data/OnlineRetail.csv', encoding='latin1')

# Quick confirmation
print(df.shape)
print(df.columns.tolist())

# %%
# Apply cleaning steps
df = df.dropna(subset=['CustomerID'])
df = df[~df['InvoiceNo'].astype(str).str.startswith('C')]
df = df[(df['Quantity'] > 0) & (df['UnitPrice'] > 0)]

# Convert InvoiceDate to datetime
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# Extract InvoiceMonth
df['InvoiceMonth'] = df['InvoiceDate'].dt.to_period('M')

# Calculate CohortMonth - first purchase month per customer
df['CohortMonth'] = df.groupby('CustomerID')['InvoiceDate'].transform('min').dt.to_period('M')

print(df.shape)
print(df[['CustomerID', 'InvoiceMonth', 'CohortMonth']].head(10))

# %%
# ============================================
# CALCULATE COHORT INDEX
# ============================================

# Extract year and month separately for both dates
invoice_year = df['InvoiceMonth'].dt.year
invoice_month = df['InvoiceMonth'].dt.month

cohort_year = df['CohortMonth'].dt.year
cohort_month = df['CohortMonth'].dt.month

# CohortIndex = number of months between InvoiceMonth and CohortMonth
df['CohortIndex'] = (invoice_year - cohort_year) * 12 + (invoice_month - cohort_month) + 1

print(df[['CustomerID', 'InvoiceMonth', 'CohortMonth', 'CohortIndex']].head(10))

# %%
# ============================================
# BUILD COHORT RETENTION MATRIX
# ============================================

cohort_data = df.groupby(['CohortMonth', 'CohortIndex'])['CustomerID'].nunique().reset_index()

cohort_matrix = cohort_data.pivot(index='CohortMonth', columns='CohortIndex', values='CustomerID')

print(cohort_matrix)

# %%
# ============================================
# CONVERT TO RETENTION PERCENTAGES
# ============================================

# Get the size of each cohort (CohortIndex 1 = starting size)
cohort_sizes = cohort_matrix[1]

# Divide every column by the cohort size, then multiply by 100
retention_matrix = cohort_matrix.divide(cohort_sizes, axis=0) * 100

print(retention_matrix.round(1))

# %%
# ============================================
# FINAL VALIDATION
# ============================================

# Confirm matrix shape
print(f"Retention matrix shape: {retention_matrix.shape}")

# Confirm all Month 1 values are 100%
print(f"All Month 1 values are 100%: {(retention_matrix[1] == 100.0).all()}")

# Show how many cohorts we have
print(f"Total cohorts: {len(retention_matrix)}")

# Show the maximum CohortIndex (how many months of data)
print(f"Maximum months tracked: {retention_matrix.columns.max()}")

# %%
# ============================================
# BUSINESS INSIGHTS SUMMARY FOR WEEK 4
# ============================================

print("""
KEY FINDINGS FROM COHORT RETENTION ANALYSIS:

1. SHARP EARLY CHURN:
   Retention drops to 15-25% by Month 2 across all cohorts.
   This means 75-85% of customers do not return after first purchase.

2. STRONGEST COHORT:
   December 2010 cohort shows the best long-term retention —
   still at 26.6% after 13 months.

3. STABILISATION PATTERN:
   After Month 2, retention stabilises between 15-35%.
   Customers who survive Month 2 tend to keep buying.

4. RECOMMENDATION:
   Focus retention efforts on Month 1 to Month 2 transition.
   An automated re-engagement email or discount offer 
   sent 3-4 weeks after first purchase could significantly 
   reduce early churn.
""")
