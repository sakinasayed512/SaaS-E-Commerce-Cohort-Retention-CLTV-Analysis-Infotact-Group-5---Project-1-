# %% [raw]
# import pandas as pd
# import numpy as np

# %%
import pandas as pd
import numpy as np

# %%
# ============================================
# WEEK 2 - COHORT RETENTION MATRIX
# Owner: Beckley
# ============================================

# PLAN:
# Step 1: Load Sakina's clean data
# Step 2: Extract InvoiceMonth from InvoiceDate
# Step 3: Group by CustomerID to find CohortMonth (first purchase month)
# Step 4: Calculate CohortIndex (months since first purchase)
# Step 5: Build pivot table - cohort retention matrix
# Step 6: Calculate retention percentages

# Columns available in dataset:
# InvoiceNo, StockCode, Description, Quantity,
# InvoiceDate, UnitPrice, CustomerID, Country

# %%
# ============================================
# WEEK 2 - DATA VALIDATION CHECKS
# ============================================

# Before building the cohort matrix, the following
# validations will be performed on Sakina's clean data:

# 1. Check for any remaining null CustomerIDs
# 2. Confirm InvoiceDate is in datetime format
# 3. Check date range of dataset (min and max date)
# 4. Count total unique customers
# 5. Count total unique invoices
# 6. Confirm no cancelled orders remain (no 'C' in InvoiceNo)

# These checks ensure the cohort matrix is built
# on fully clean and reliable data

# %%
# ============================================
# LOADING THE DATASET
# ============================================
import pandas as pd
import numpy as np

df = pd.read_csv('data/OnlineRetail.csv', encoding = 'latin1')
print(df.shape)
print(df.head())
